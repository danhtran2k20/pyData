# %%
import numpy as np
import pandas as pd
import warnings

# %%
emp = pd.read_excel('employees.xls')
dep = pd.read_excel('departments.xls')
job = pd.read_excel('jobs.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
emp.shape
# Out:
# (107, 11)

# %%
job.shape
# Out:
# (19, 4)

# %%
dep.shape
# Out:
# (27, 4)

# %%
emp.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0          100     Steven      King     SKING  515.123.4567
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4          104      Bruce     Ernst    BERNST  590.423.4568
#
#              HIRE_DATE   JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0  2003-06-17 00:00:00  AD_PRES   24000             NaN         NaN
# 1  2005-09-21 00:00:00    AD_VP   17000             NaN       100.0
# 2  2001-01-13 00:00:00    AD_VP   17000             NaN       100.0
# 3  2006-01-03 00:00:00  IT_PROG    9000             NaN       102.0
# 4  2007-05-21 00:00:00  IT_PROG    6000             NaN       103.0
#
#    DEPARTMENT_ID
# 0           90.0
# 1           90.0
# 2           90.0
# 3           60.0
# 4           60.0

# %%
emp = emp[['EMPLOYEE_ID', 'FIRST_NAME', 'SALARY', 'JOB_ID', 'DEPARTMENT_ID']]

# %%
emp.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  SALARY   JOB_ID  DEPARTMENT_ID
# 0          100     Steven   24000  AD_PRES           90.0
# 1          101      Neena   17000    AD_VP           90.0
# 2          102        Lex   17000    AD_VP           90.0
# 3          103  Alexander    9000  IT_PROG           60.0
# 4          104      Bruce    6000  IT_PROG           60.0

# %%
job
# Out:
#         JOB_ID                        JOB_TITLE  MIN_SALARY  MAX_SALARY
# 0   AC_ACCOUNT                Public Accountant        4200        9000
# 1       AC_MGR               Accounting Manager        8200       16000
# 2      AD_ASST         Administration Assistant        3000        6000
# 3      AD_PRES                        President       20080       40000
# 4        AD_VP    Administration Vice President       15000       30000
# 5   FI_ACCOUNT                       Accountant        4200        9000
# 6       FI_MGR                  Finance Manager        8200       16000
# 7       HR_REP   Human Resources Representative        4000        9000
# 8      IT_PROG                       Programmer        4000       10000
# 9       MK_MAN                Marketing Manager        9000       15000
# 10      MK_REP         Marketing Representative        4000        9000
# 11      PR_REP  Public Relations Representative        4500       10500
# ...

# %%
dep
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 11 columns):
# EMPLOYEE_ID       107 non-null int64
# FIRST_NAME        107 non-null object
# LAST_NAME         107 non-null object
# EMAIL             107 non-null object
# PHONE_NUMBER      107 non-null object
# HIRE_DATE         107 non-null object
# JOB_ID            107 non-null object
# SALARY            107 non-null int64
# COMMISSION_PCT    35 non-null float64
# MANAGER_ID        106 non-null float64
# DEPARTMENT_ID     106 non-null float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 9.3+ KB

# %%
emp.isnull().sum()
# Out:
# EMPLOYEE_ID        0
# FIRST_NAME         0
# LAST_NAME          0
# EMAIL              0
# PHONE_NUMBER       0
# HIRE_DATE          0
# JOB_ID             0
# SALARY             0
# COMMISSION_PCT    72
# MANAGER_ID         1
# DEPARTMENT_ID      1
# dtype: int64

# %%
# inner join
emp = pd.merge(left=emp, right=job[['JOB_ID', 'JOB_TITLE']], left_on='JOB_ID', 
               right_on='JOB_ID', how='inner')
# emp = pd.merge(emp, job[['JOB_ID', 'JOB_TITLE']])

# %%
emp.head(10)
# Out:
#    EMPLOYEE_ID FIRST_NAME  SALARY      JOB_ID  DEPARTMENT_ID  \
# 0          100     Steven   24000     AD_PRES           90.0
# 1          101      Neena   17000       AD_VP           90.0
# 2          102        Lex   17000       AD_VP           90.0
# 3          103  Alexander    9000     IT_PROG           60.0
# 4          104      Bruce    6000     IT_PROG           60.0
# 5          105      David    4800     IT_PROG           60.0
# 6          106      Valli    4800     IT_PROG           60.0
# 7          107      Diana    4200     IT_PROG           60.0
# 8          108      Nancy   12008      FI_MGR          100.0
# 9          109     Daniel    9000  FI_ACCOUNT          100.0
#
#                        JOB_TITLE
# 0                      President
# 1  Administration Vice President
# 2  Administration Vice President
# 3                     Programmer
# 4                     Programmer
# 5                     Programmer
# 6                     Programmer
# ...

# %%
emp.shape
# Out:
# (107, 6)

# %%
emp = pd.merge(left=emp, right=dep[['DEPARTMENT_ID', 'DEPARTMENT_NAME']], left_on='DEPARTMENT_ID', right_on='DEPARTMENT_ID', 
               how='inner')

# %%
emp.head(10)
# Out:
#    EMPLOYEE_ID FIRST_NAME  SALARY      JOB_ID  DEPARTMENT_ID  \
# 0          100     Steven   24000     AD_PRES           90.0
# 1          101      Neena   17000       AD_VP           90.0
# 2          102        Lex   17000       AD_VP           90.0
# 3          103  Alexander    9000     IT_PROG           60.0
# 4          104      Bruce    6000     IT_PROG           60.0
# 5          105      David    4800     IT_PROG           60.0
# 6          106      Valli    4800     IT_PROG           60.0
# 7          107      Diana    4200     IT_PROG           60.0
# 8          108      Nancy   12008      FI_MGR          100.0
# 9          109     Daniel    9000  FI_ACCOUNT          100.0
#
#                        JOB_TITLE DEPARTMENT_NAME
# 0                      President       Executive
# 1  Administration Vice President       Executive
# 2  Administration Vice President       Executive
# 3                     Programmer              IT
# ...

# %%
emp.shape
# Out:
# (106, 7)

# %%
emp = pd.read_excel('employees.xls')

# %%
emp.shape
# Out:
# (107, 11)

# %%
emp[emp['DEPARTMENT_ID'].isnull()]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME   EMAIL        PHONE_NUMBER  \
# 78          178  Kimberely     Grant  KGRANT  011.44.1644.429263
#
#               HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 78  2007-05-24 00:00:00  SA_REP    7000            0.15       149.0
#
#     DEPARTMENT_ID
# 78            NaN

# %%
emp = emp[['EMPLOYEE_ID', 'FIRST_NAME', 'SALARY', 'JOB_ID', 'DEPARTMENT_ID']]

# %%
emp = pd.merge(left=emp, right=dep[['DEPARTMENT_ID', 'DEPARTMENT_NAME']], left_on='DEPARTMENT_ID', right_on='DEPARTMENT_ID', 
               how='left') # how : {'left', 'right', 'outer', 'inner'}, default 'inner'

# %%
emp.shape
# Out:
# (107, 6)

# %%
emp[emp['DEPARTMENT_ID'].isnull()]
# Out:
#     EMPLOYEE_ID FIRST_NAME  SALARY  JOB_ID  DEPARTMENT_ID DEPARTMENT_NAME
# 78          178  Kimberely    7000  SA_REP            NaN             NaN
