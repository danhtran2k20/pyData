# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
iris = sns.load_dataset('iris')

# %%
iris.shape # thuộc tính property
# Out:
# (150, 5)

# %%
iris.head() # hàm/ phương thức method
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.distplot(iris['petal_length']);

# %%
np.histogram(iris['petal_length'])
# Out:
# (array([37, 13,  0,  3,  8, 26, 29, 18, 11,  5], dtype=int64),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]))

# %%
iris['petal_length'].describe()
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
# iris['petal_length'].value_counts()
from scipy import stats
stats.mode(iris['petal_length'])
# Out:
# ModeResult(mode=array([1.4]), count=array([13]))

# %%
sns.distplot(iris['petal_length'], kde=False);

# %%
sns.distplot(iris['petal_length'], hist=False);

# %%
sns.distplot(iris['petal_length']);

# %%
data = iris[iris['species']=='setosa'] # vẽ petal_length cho loại setosa
sns.distplot(data['petal_length']);

# %%
data['petal_length'].describe()
# Out:
# count    50.000000
# mean      1.462000
# std       0.173664
# min       1.000000
# 25%       1.400000
# 50%       1.500000
# 75%       1.575000
# max       1.900000
# Name: petal_length, dtype: float64

# %%
# vẽ data titanic cho biến fare
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(titanic['fare']);

# %%
sns.distplot(titanic['fare'], rug=True, hist=False);

# %%
# vẽ data tips cho biến tip
tips = sns.load_dataset('tips')

# %%
sns.distplot(tips['tip'], rug=True, rug_kws={"color": "r"},
                  kde_kws={"color": "k", "lw": 3, "label": "KDE"},
                  hist_kws={"histtype": "step", "linewidth": 3,
                            "alpha": 1, "color": "g"});
