# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x="petal_length", y="petal_width", data=iris);

# %%
sns.scatterplot(x="petal_length", y="petal_width", hue='species', data=iris);

# %%
sns.swarmplot(x="species", y="petal_length", data=iris);

# %%
sns.swarmplot(y="species", x="petal_length", data=iris);

# %%
# kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }
sns.jointplot(x="petal_length", y="petal_width", data=iris, kind='reg', color='red');

# %%
# vẽ joinplot cho data là salary với x:Salary và y:Age
data = pd.read_csv("data/salary.csv", index_col=0)

# %%
data.head()
# Out:
#     District    Salary  Age        English            Education  Gender
# 0   Brooklyn  120000.0   31  Only language      Academic degree    Male
# 1   Brooklyn   45000.0   28  Only language      Academic degree  Female
# 2  Manhatten   85000.0   54  Only language      Academic degree    Male
# 3  Manhatten   12000.0   45  Only language  High school diploma  Female
# 4   Brooklyn       0.0   75      Very well      Academic degree  Female

# %%
sns.jointplot(x="Salary", y="Age", data=data);

# %%
sns.jointplot(x="Salary", y="Age", data=data.sample(200));

# %%
sns.jointplot(x="Salary", y="Age", data=data[data['Salary']<500000].sample(300, random_state=1), 
              xlim=(0, 500000), ylim=(0, 100));
