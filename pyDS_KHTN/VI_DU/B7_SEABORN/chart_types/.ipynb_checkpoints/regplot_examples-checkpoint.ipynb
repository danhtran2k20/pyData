# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.regplot(x="petal_length", y="petal_width", data=iris);

# %%
anscombe = sns.load_dataset('anscombe')

# %%
anscombe.shape
# Out:
# (44, 3)

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sns.regplot(data=anscombe.query("dataset=='II'"), x='x', y='y', order=3);

# %%
sns.regplot(x="sepal_length", y="sepal_width", data=iris);

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.residplot(x="sepal_length", y="sepal_width", data=iris);

# %%
# Hàm này sẽ hồi quy y trên x (có thể là hồi quy mạnh hoặc đa thức) và sau đó vẽ một biểu đồ tán xạ của phần dư. 
# Phần dư: giá trị y thực tế - giá trị y hồi quy (quan sát – dự báo)
# Nếu các trị phần dư phân tán ngẫu nhiên quanh giá trị zero (đường ngang) thì coi như phân tích hồi quy phù hợp.

# %%
sns.regplot(x="petal_length", y="petal_width", data=iris, x_bins=3);

# %%
sns.regplot(x="petal_length", y="petal_width", data=iris);

# %%
# nói thêm
sns.lmplot(x="petal_length", y="petal_width", data=iris, hue='species');

# %%
sns.lmplot(x="petal_length", y="petal_width", data=iris, hue='species', fit_reg=False);

# %%
sns.lmplot(x="petal_length", y="petal_width", data=iris, hue='species', scatter=False);
